# %%
# we need headers to disguise our bot as a browser

headers = {
    "Connection": "keep-alive",
    "Cache-Control": "max-age=0",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    "User-Agent": "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/34.0.1847.131 Safari/537.36",
    "Accept-Encoding": "gzip,deflate,sdch",
    "Accept-Language": "zh-CN,zh;q=0.8,en-US;q=0.6,en;q=0.4,zh-TW;q=0.2",
}

import requests
from scrapy.http import TextResponse

r = requests.get('https://twitter.com/Chase', 
                 headers = headers)

response = TextResponse(r.url, body = r.text, encoding = 'utf-8')

# there is a response we need to handle
response
# Out:
# <200 https://twitter.com/Chase>

# %%
from scrapy import Item, Field


class DocumentItem(Item):
    # define the fields for your item here like:
    # name = scrapy.Field()
    abstract = Field()

# %%
document=dict(
    abstract='//*[@id="stream-item-tweet-870444879352012800"]/div[1]/div[2]'
)

# %%
response.body
# Out:
# b'<!DOCTYPE html>\n<html lang="zh-cn" data-scribe-reduced-action-queue="true">\n  <head>\n    \n    \n    \n    \n    \n    \n    \n    <meta charset="utf-8">\n    \n    <noscript><meta http-equiv="refresh" content="0; URL=https://mobile.twitter.com/i/nojs_router?path=%2FChase"></noscript>\n      <script  nonce="ymRDhxQoI0hdr5rOTZxaRw==">\n        !function(){window.initErrorstack||(window.initErrorstack=[]),window.onerror=function(r,i,n,o,t){r.indexOf("Script error.")>-1||window.initErrorstack.push({errorMsg:r,url:i,lineNumber:n,column:o,errorObj:t})}}();\n      </script>\n    \n    \n  \n  <script id="bouncer_terminate_iframe" nonce="ymRDhxQoI0hdr5rOTZxaRw==">\n    if (window.top != window) {\n  window.top.postMessage({\'bouncer\': true, \'event\': \'complete\'}, \'*\');\n}\n  </script>\n  <script id="ttft_boot_data" nonce="ymRDhxQoI0hdr5rOTZxaRw==">\n    window.ttftData={"transaction_id":"0060ae9f00437881.9a7263838b9f2eba\\u003c:00fc9364000d4290","server_request_start_time":149694
# ...

# %%
abstract_xpath='//*[@id="stream-item-tweet-869176524527722496"]/div[1]/div[2]/div[2]/p'

# %%
response.xpath(abstract_xpath).extract()
# Out:
# ['<p class="TweetTextSize TweetTextSize--normal js-tweet-text tweet-text" lang="en" data-aria-label-part="0">This <a href="/hashtag/MemorialDay?src=hash" data-query-source="hashtag_click" class="twitter-hashtag pretty-link js-nav" dir="ltr"><s>#</s><b>MemorialDay</b></a>, we honor the military and their families who have given all to ensure our freedom. <a href="/hashtag/CarryTheLoad?src=hash" data-query-source="hashtag_click" class="twitter-hashtag pretty-link js-nav" dir="ltr"><s>#</s><b>CarryTheLoad</b></a><a href="https://t.co/4BXfy3F744" class="twitter-timeline-link u-hidden" data-pre-embedded="true" dir="ltr">pic.twitter.com/4BXfy3F744</a></p>']
